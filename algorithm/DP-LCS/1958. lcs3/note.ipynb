# %%
verbose = True
verboses = [True for _ in range(10)]

# %%
str1 = "abcdefghijklmn"
str2 = "bdefg"
str3 = "bde"


N = len(str1)
M = len(str2)
L = len(str3)

# %%
dp = [ [ ['' for _ in range(L+1)] for _ in range(M+1) ] for _ in range(N+1) ]

# %%
dp = [ [ ['' for _ in range(L+1)] for _ in range(M+1) ] for _ in range(N+1) ]

for n in range(1,N+1):
    letn = str1[n-1]
    for m in range(1,M+1):
        letm = str2[m-1]
        for l in range(1,L+1):
            letl = str3[l-1]
            if letl == letm :
                dp[n][m][l] = dp[n][m-1][l-1] + letl
            else:
                dp[n][m][l] = max(dp[n][m-1][l], dp[n][m][l-1], key= lambda x: len(x))
        print(dp[n][m])
    break
# Out:
# ['', 'b', 'b', 'b']
# ['', 'b', 'bd', 'bd']
# ['', 'b', 'bd', 'bde']
# ['', 'b', 'bd', 'bde']
# ['', 'b', 'bd', 'bde']

# %%
dp = [ [ [0 for _ in range(L+1)] for _ in range(M+1) ] for _ in range(N+1) ]

for n in range(1,N+1):
    letn = str1[n-1]
    for m in range(1,M+1):
        letm = str2[m-1]
        for l in range(1,L+1):
            letl = str3[l-1]
            if letl == letm and letn == letm:
                dp[n][m][l] = dp[n-1][m-1][l-1] + 1
            else:
                dp[n][m][l] = max(dp[n-1][m][l], dp[n][m-1][l], dp[n][m][l-1])

print(dp[-1][-1][-1])
# Out:
# 3
