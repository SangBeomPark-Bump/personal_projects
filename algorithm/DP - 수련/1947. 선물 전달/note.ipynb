# %%
verbose = True
verboses = [True for _ in range(10)]

# %%
N = 7

# %%
dp = [0 for _ in range(N)]

div = int(1e9)

# %%
dp[2] = 1

# %%
dp = [[0,0] for _  in range(N+1)]
dp[0] = [1, 0]
dp[1] = [0,1]

for n in range(2, N+1):
    dp[n][0] = dp[n-1][0] * (n-1) + dp[n-1][1]
    dp[n][1] = n * dp[n-1][0]
    print(dp[n])
# Out:
# [1, 0]
# [2, 3]
# [9, 8]
# [44, 45]
# [265, 264]
# [1854, 1855]

# %%
dp = [ 0 for _  in range(N+1)]
dp[0] = 1
dp[1] = 0

for n in range(2, N+1):
    dp[n] = (n-1) * (dp[n-2] + dp[n-1] )
print(dp[N])
# Out:
# 1854
