# %%
verbose = True
verboses = [True for _ in range(10)]

# %%
N = 5
arr =  list(map(int, "5 4 3 1 2".split()))

# %%
N = 5
arr =  list(map(int, "5 2 4 1 3".split()))

# %%
N = 5
arr =  list(map(int, "1 2 3 4 5".split()))

# %%
import random

N = 7
arr = list(range(1, N+1))
random.shuffle(arr)
arr
# Out:
# [3, 4, 1, 6, 2, 7, 5]

# %%
arr
# Out:
# [2, 5, 1, 3, 4, 6, 7]

# %%
dp = [ 0 for _ in range(N+1)]
ans = 0
for i in arr:
    ans = max(dp[i-1] +1, ans)
    dp[i] = dp[i-1] +1
print(N - ans)
# Out:
# [0, 1, 2, 1, 2, 3, 1, 2]
# 4
