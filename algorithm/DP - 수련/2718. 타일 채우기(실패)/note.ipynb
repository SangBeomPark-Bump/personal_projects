# %%
verbose = True
verboses = [True for _ in range(10)]

# %%
1421
# Out:
# 1421

# %%
N = 7

# %%
dp = [ 0 for _ in range(N+1)]
dp[0] = 1
dp[1] = 1
dp[2] = dp[0] * 4 + dp[1] *1
dp[3] = dp[0] *2 +dp[1] * 4 + dp[2] *1


for n in range(4, N+1):
    dp[n] = dp[n-4] + dp[n-3] * 2 + dp[n-2] * 4 + dp[n-1]
dp
# Out:
# [1, 1, 5, 11, 34, 89, 252, 687]
