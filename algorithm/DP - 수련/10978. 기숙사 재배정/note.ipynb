# %%
verbose = True
verboses = [True for _ in range(10)]

# %%
N = 2

# %%
N
# Out:
# 2

# %%
dp = [ 0 for _ in range(21)]
dp[2] = 1

for n in range(3,21):
    dp[n] = (n-1)*(dp[n-1] + dp[n-2])
dp
# Out:
# [0,
#  0,
#  1,
#  2,
#  9,
#  44,
#  265,
#  1854,
#  14833,
#  133496,
#  1334961,
#  14684570,
#  176214841,
#  2290792932,
#  32071101049,
#  481066515734,
#  7697064251745,
#  130850092279664,
#  2355301661033953,
#  44750731559645106,
#  895014631192902121]
