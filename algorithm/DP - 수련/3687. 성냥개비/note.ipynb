# %%
verbose = True
verboses = [True for _ in range(10)]

# %%
N = 7

numbers = [6, 2, 5, 5, 4, 5, 6, 3, 7, 6]

# %%
INF = float("inf")

dp = [ INF for _ in range(101)]

# %%
dp[2] = 1
dp[3] = 7
dp[4] = 4
dp[5] = 2
dp[6] = 6
dp[7] = 8

# %%
dp[:10]
# Out:
# [inf, inf, 1, 7, 4, 2, 6, 8, inf, inf]

# %%
# n = 8
for n in range(8, 101):
    for number, value in enumerate(numbers):
        prev_index = n - value
        if prev_index >1:
            prev_number_str = str(dp[prev_index])
            for i in range(len(prev_number_str) +1 ):
                if i == 0 and number == 0:
                    continue
                temp_number = int(prev_number_str[0:i] + str(number) + prev_number_str[i:])
                dp[n] = min(dp[n], temp_number)
    # print(dp[n])
# Out:
# 10
# 18
# 22
# 20
# 28
# 68
# 88
# 108
# 188
# 200
# 208
# 288
# 688
# 888
# 1088
# 1888
# 2008
# 2088
# 2888
# 6888
# 8888
# 10888
# 18888
# 20088
# 20888
# 28888
# 68888
# 88888
# 108888
# 188888
# 200888
# 208888
# 288888
# 688888
# 888888
# 1088888
# 1888888
# 2008888
# 2088888
# 2888888
# 6888888
# 8888888
# 10888888
# 18888888
# 20088888
# 20888888
# 28888888
# 68888888
# 88888888
# 108888888
# 188888888
# 200888888
# 208888888
# 288888888
# 688888888
# 888888888
# 1088888888
# 1888888888
# 2008888888
# 2088888888
# 2888888888
# 6888888888
# 8888888888
# 10888888888
# 18888888888
# 20088888888
# 20888888888
# 28888888888
# 68888888888
# 88888888888
# 108888888888
# 188888888888
# 200888888888
# 208888888888
# 288888888888
# 688888888888
# 888888888888
# 1088888888888
# 1888888888888
# 2008888888888
# 2088888888888
# 2888888888888
# 6888888888888
# 8888888888888
# 10888888888888
# 18888888888888
# 20088888888888
# 20888888888888
# 28888888888888
# 68888888888888
# 88888888888888
# 108888888888888
# 188888888888888

# %%
dp2 = [-INF, -INF]

for n in range(2, 101):
    if n%2 ==1:
        temp = int('7' + "1"* ((n//2) - 1))
    else:
        temp = int("1"* ((n//2)))
    dp2.append(temp)

dp2[:10]
# Out:
# [-inf, -inf, 1, 7, 11, 71, 111, 711, 1111, 7111]
