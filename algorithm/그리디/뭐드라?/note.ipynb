# %%
INF = float('inf')

# %%
N = 11

raw_arr = """1 4
3 5
0 6
5 7
3 8
5 9
6 10
8 11
8 12
2 13
12 14""".split('\n')

arr =  [list(map(int,row.split())) for row in raw_arr]

# %%
arr =  [list(map(int,row.split())) for row in raw_arr]
arr.sort(reverse= True)
arr
# Out:
# [[12, 14],
#  [8, 12],
#  [8, 11],
#  [6, 10],
#  [5, 9],
#  [5, 7],
#  [3, 8],
#  [3, 5],
#  [2, 13],
#  [1, 4],
#  [0, 6]]

# %%
latest = (0, 0)

while arr:
    start, end = arr.pop()

    factor = latest[0]
    if start >= latest[1]:
        factor += 1
    
    latest = max( latest, (factor, end), key=lambda x: (x[0], -x[1]))
    print(latest)

# print(latest[0])arr
# Out:
# (1, 6)
# (1, 4)
# (1, 4)
# (1, 4)
# (1, 4)
# (2, 7)
# (2, 7)
# (2, 7)
# (3, 11)
# (3, 11)
# (4, 14)
