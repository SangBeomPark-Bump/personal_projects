# %%
verbose = True
verboses = [True for _ in range(10)]
INF = float('inf')

# %%
N = 4

# %%
dp = [ 0 for _ in range(N+1)]
dp[2] = 2


for i in range(3, N+1):
    dp[i] = i * (i-1) * (dp[i-1] + dp[i-2])
print(dp[-1])
# Out:
# 168
