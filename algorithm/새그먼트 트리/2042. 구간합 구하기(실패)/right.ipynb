# %%
N, M, K = 5, 2, 2
raw_arr_n = """1
2
3
4
5""".split('\n')

arr_n =  [int(number) for number in raw_arr_n]

raw_arr_o = """1 3 6
2 2 5
1 5 2
2 3 5""".split('\n')

arr_o =  [tuple(map(int,row.split())) for row in raw_arr_o]
