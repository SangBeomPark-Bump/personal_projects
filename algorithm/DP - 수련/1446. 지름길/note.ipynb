# %%
verbose = True
verboses = [True for _ in range(10)]

# %%
N, D = 5, 150


raw_arr = """0 50 10
0 50 20
50 100 10
100 151 10
110 140 90""".split('\n')

arr =  [tuple(map(int,row.split())) for row in raw_arr]

# %%
N, D = 8, 900


raw_arr = """0 10 9
20 60 45
80 190 100
50 70 15
160 180 14
140 160 14
420 901 5
450 900 0""".split('\n')

arr =  [tuple(map(int,row.split())) for row in raw_arr]

# %%
dp = [ [i for i in range(D+1)] for _ in range(N+1)]

for n in range(1,N+1):
    for d in range(1, D+1):
        case1 = d
        for start, end, distance in arr[:n]:
            if d == end:
                case1 = min(case1, dp[n][start] + distance)
        case2 = dp[n][d-1] +1
        case3= dp[n-1][d-1] + 1 
        dp[n][d] = min(case1, case2, case3)
    print(start, end, distance, dp[n][-1])
# Out:
# 0 10 9 899
# 20 60 45 899
# 80 190 100 889
# 50 70 15 884
# 160 180 14 884
# 140 160 14 882
# 420 901 5 882
# 450 900 0 432

# %%
dp = [i for i in range(D+1)]

# for n in range(1,N+1):
for d in range(1, D+1):
    case1 = d
    for start, end, distance in arr[:n]:
        if d == end:
            case1 = min(case1, dp[start] + distance)
    case2 = dp[d-1] +1
    # case3= dp[n-1][d] + 1 
    dp[d] = min(case1, case2, case3)
print(start, end, distance)
# Out:
# 450 900 0

# %%
dp[-1]
# Out:
# 432
