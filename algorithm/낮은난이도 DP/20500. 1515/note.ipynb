# %%
verbose = True
verboses = [True for _ in range(10)]

# %%
N = 7

div = int(1e9) + 7

# %%
dp = [ [0, 0, 0] for _ in range(N)]
dp[0][0] = 1

# %%
n = 1

dp[n] = [ dp[n-1][2] + dp[n-1][1], dp[n-1][0] + dp[n-1][2], dp[n-1][0] + dp[n-1][1] ]
print(dp[n])
# Out:
# [0, 1, 1]

# %%
dp = [ [0, 0, 0] for _ in range(N)]
dp[0][0] = 1

for n in range(1, N):
    dp[n] = [ dp[n-1][2] + dp[n-1][1], dp[n-1][0] + dp[n-1][2], dp[n-1][0] + dp[n-1][1] ]
print(dp)
# Out:
# [[1, 0, 0], [0, 1, 1], [2, 1, 1], [2, 3, 3], [6, 5, 5], [10, 11, 11], [22, 21, 21]]

# %%
dp = [1, 0, 0]

for n in range(1, N):
    temp = sum(dp)
    dp = [ temp - dp[i] for i in range(3)]

print(dp[1])
# Out:
# 11
