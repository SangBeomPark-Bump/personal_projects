# %%
INF = float('inf')

# %%
string = "QWERTYTREWQWERT"
N = len(string)

# %%
string = "AAAA"
N = len(string)

# %%
pel = [ [False for _ in range(N+1)] for _ in range(N+1)]
for n in range(N+1):
    pel[n][n] = True
    if n+1 <=N:
        pel[n][n+1] = True

for factor in range(2, N+1):
    for start in range(N+1-factor):
        end = start + factor
        if pel[start+1][end-1] and string[start] == string[end-1]:
            pel[start][end] = True
# pel

# %%
dp = [INF for _ in range(N+1)]
dp[0] = 0
for start in range(N):
    for end in range(start+1, N+1):
        if pel[start][end]:
            dp[end] = min(dp[end], dp[start] + 1)
print(dp[-1])
# Out:
# 1

# %%
pel = [ [False for _ in range(N+1)] for _ in range(N+1)]
visited = [ [False for _ in range(N+1)] for _ in range(N+1)]
dp = [n for n in range(N+1)]
dp[0] = 0

def dfs(start, end):
    if end - start <=1:
        return True
    
    if visited[start][end]:
        return pel[start][end]

    for endindex in range(end-1, start, -1):
        visited[start][endindex+1] = True

        if string[endindex] == string[start]:
            if dfs(start +1, endindex):
                dp[endindex+1] = min(dp[endindex+1], dp[start]+1)
    dfs(start+1, end)

    pel[start][end] = dfs(start+1, end-1) and string[start] == string[end-1]
    return pel[start][end]

dfs(0, N)
# Out:
# False

# %%
pel
# Out:
# [[False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
# ...

# %%
string
# Out:
# 'QWERTYTREWQWERT'

# %%
dp
# Out:
# [0, 1, 2, 3, 4, 5, 6, 5, 4, 3, 2, 1, 4, 5, 6, 7]
