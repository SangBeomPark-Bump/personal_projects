# %%
verbose = True
verboses = [True for _ in range(10)]

# %%
N, M, K = 6, 3, 6

raw_arr = """1
2
3
1
2
1""".split('\n')

arr =  [int(number) for number in raw_arr]

# %%
dp = [0 for _ in range(N+1)]
