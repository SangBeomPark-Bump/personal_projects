# %%
verbose = True
verboses = [True for _ in range(10)]

# %%
N = 4
string = "X"+"ABBA"

# %%
N = 12
string = "X" + "AAABBBAAABBB"

# %%
dp = [ [0, 0] for _ in range(N+1)]

for n in range(1, N+1):
    dp[n] = dp[n-1][::]
    if string[n] == 'B':
        dp[n][0] = min(dp[n-1]) + 1
    else:
        dp[n][1] = min(dp[n-1]) + 1
    print(dp[n])

print(dp[-1][0])
# Out:
# [0, 1]
# [0, 1]
# [0, 1]
# [1, 1]
# [2, 1]
# [2, 1]
# [2, 2]
# [2, 3]
# [2, 3]
# [3, 3]
# [4, 3]
# [4, 3]
# 4

# %%
dp = [0, 0]

for n in range(1, N+1):
    dp = [min(dp) +1 if string[n] == "B" else dp[0]  ,  min(dp) +1 if string[n] == "A" else dp[1]]

print(dp[0])
# Out:
# [0, 1]
# [0, 1]
# [0, 1]
# [1, 1]
# [2, 1]
# [2, 1]
# [2, 2]
# [2, 3]
# [2, 3]
# [3, 3]
# [4, 3]
# [4, 3]
# 4
