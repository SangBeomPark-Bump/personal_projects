# %%
verbose = True
verboses = [True for _ in range(10)]

# %%
N, M = 3, 4


raw_arr = """1 2 4
1 3 3
2 3 -2
3 1 -2""".split('\n')

arr =  [tuple(map(int,row.split())) for row in raw_arr]

# %%
N, M = 3, 4


raw_arr = """1 2 4
1 3 3
2 3 -4
3 1 -2""".split('\n')

arr =  [tuple(map(int,row.split())) for row in raw_arr]

# %%
nodes = [ [] for _ in range(N+1) ]
for start, end, time in arr:
    nodes[start].append((end, time))
nodes
# Out:
# [[], [(2, 4), (3, 3)], [(3, -2)], [(1, -2)]]

# %%
from collections import deque
INF = float("INF")
dp = [[INF] * (N+1) for _ in range(N+1)]
dp[0][1] = 0

# for _ in range(N-1):
n = 1
dp[n][1] = 0
# visited = [False] * (N+1)
# visited[1] = True
que = deque([1])
while que:
    cur_node = que.popleft()
    print(nodes[cur_node])
    for next_node, next_time in nodes[cur_node]:
        cur_time = dp[n-1][cur_node] + next_time
        print(cur_node, next_node, cur_time, next_time)

        if dp[n][next_node] > cur_time :
            # visited[next_node] = True
            dp[n][next_node] = cur_time
            que.append(next_node)
    # print('-' * 50)
    print(dp)
# Out:
# [(2, 4), (3, 3)]
# 1 2 4 4
# 1 3 3 3
# [[inf, 0, inf, inf], [inf, 0, 4, 3], [inf, inf, inf, inf], [inf, inf, inf, inf]]
# [(3, -2)]
# 2 3 inf -2
# [[inf, 0, inf, inf], [inf, 0, 4, 3], [inf, inf, inf, inf], [inf, inf, inf, inf]]
# [(1, -2)]
# 3 1 inf -2
# [[inf, 0, inf, inf], [inf, 0, 4, 3], [inf, inf, inf, inf], [inf, inf, inf, inf]]

# %%
from collections import deque
INF = float("INF")
dp = [[INF] * (N+1) for _ in range(N+1)]
dp[0][1] = 0

for n in range(1, N+1):
    dp[n][1] = 0
    # visited = [False] * (N+1)
    # visited[1] = True
    que = deque([1])
    while que:
        cur_node = que.popleft()
        # print(nodes[cur_node])
        for next_node, next_time in nodes[cur_node]:
            cur_time = dp[n-1][cur_node] + next_time
            # print(cur_node, next_node, cur_time, next_time)

            if dp[n][next_node] > cur_time :
                # visited[next_node] = True
                dp[n][next_node] = cur_time
                que.append(next_node)
        # print('-' * 50)
        # print(dp)

if dp[-1][1] <0 :
    print(-1)
else:
    for time in dp[-1][2:]:
        if time == float('inf'):
            print(-1)
        else:
            print(time)
# Out:
# 4
# 2
